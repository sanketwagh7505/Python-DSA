# %% [markdown]
# ### 16. Write a program that will give you the in hand salary after deduction.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
salary = float(input("Enter your salary: "))

if salary in range(500000, 1000000):
    salary = salary*0.1
elif salary in range(1100000, 2000000):
    salary = salary *0.2
elif salary > 2000000:
    salary = salary * 0.30
else:
    print("no tax") 

print("Salary after Tax Cutting", salary)    


HRA = salary *0.10
DA = salary *0.05 
PF = salary *0.03  


remain = salary -(HRA+DA+PF)

# if remain in range(10000,99999):
#     print("In hand salary after tax /HRA/DA/PF cutting", remain/1000, "k")
# elif remain in range(100000,9999999):
#     print("In hand salary after tax /HRA/DA/PF cutting", remain/100000, "lac")
# else:
#       print("In hand salary after tax /HRA/DA/PF cutting", remain/10000000, "Cr")  


if (remain > 10000) and (remain <=99999):
    print("In hand salary after tax /HRA/DA/PF cutting", round(remain/1000, 5 ), "k")
elif (remain >100000) and (remain <= 9999999):
    print("In hand salary after tax /HRA/DA/PF cutting", round(remain/100000, 5), "lac")
else: 
    print("In hand salary after tax /HRA/DA/PF cutting", round(remain/10000000,5), "Cr")
# Out:
# no tax
# Salary after Tax Cutting 456789.0
# In hand salary after tax /HRA/DA/PF cutting 3.74567 lac
